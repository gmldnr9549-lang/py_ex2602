# %%
class person():
    def__init__(self, name, age, hobby):
       self.hello = '안녕하세요'

# %%
# 클래스 속성

class presin():
    folder = [] # 클래스 속성 -> 클래스에 속한다(공공제) 모든 인스턴스에서 접근이 가능하다

    def add_files(self, file):
        self.folder.append(file)
    
jin = person()
jin.add_files('img')

paul = person()
paul.add_files('img')

print(jin.folder)
print(paul.folder)

# %%
#모듈 -> 변수, 함수, 클래스 등을 모아서 파알로 저장해둔 것

#패키지-> 여러개의 모듈을 폴더로 묶어 체계적으로 관리하는 것
       #-> 관련된 기능들을 하나의 디렉터리 구조로 구성한 것
       #-> 대규모 프로그램에서 코드 관리롸 구조화를 위해 사용하는 단위

# %%
import ex1

ex1.fun1()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import ex1
#       3 ex1.fun1()
#
# ModuleNotFoundError: No module named 'ex1'
