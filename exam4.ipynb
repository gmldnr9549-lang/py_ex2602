# %%
# 어노테이션: 어떤 타입인지 미리 적어두는 표시


def add(a:int,b:int) -> int:
    return a + b

# add(10,20)
add("안녕", "반가워")

numbers: list[int] = [1, 2, 3]

person: dict[str, int] = {
    "age" : 30,
    "heigh": 170
}

print(numbers)
print(person)
# Out:
# [1, 2, 3]
# {'age': 30, 'heigh': 170}
