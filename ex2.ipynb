# %%
# 빈 클래스 만들기
class person:
    pass

# %%
class person:
    def hello(self):
        print("hello")

    def hi(self):
        self.hello()

jin = person()
jin.hi()
# Out:
# hello

# %%
class person():
    def__init__(self, name, age, hobby):
       elf.hello = "안녕하세요"
       elf.name = name
       elf.age = age
       elf.hobby = hobby

    def hi(self):
        print("{}, 저는 {}입니다.".format(self.hello, self.name)

jin = person('진', 22, '운동')
jin.hi()
# Out:
#   Cell In[17], line 2
#     def__init__(self, name, age, hobby):
#                                        ^
# SyntaxError: invalid syntax
